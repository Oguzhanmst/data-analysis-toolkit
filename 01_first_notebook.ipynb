# %% [markdown]
# # Data Analysis Toolkit
# ## Step 01 - Create and Display Sample Data
#
# In this step, I will create a small sample dataset and display it as a pandas DataFrame.

# %%
import pandas as pd 
print("pandas imported successfully")
# Out:
# pandas imported successfully

# %%
orders = pd.DataFrame({
    "order_id": [1001, 1002, 1003, 1004, 1005],
    "customer_id": [1, 2, 1, 3, 4],
    "product": ["Mouse", "Chair", "T-Shirt", "Keyboard", "Shampoo"],
    "category": ["Electronics", "Home", "Fashion", "Electronics", "Beauty"],
    "quantity": [2, 1, 3, 1, 2],
    "unit_price": [500, 1200, 300, 750, 200],
    "order_date": ["2025-01-05", "2025-01-12", "2025-02-03", "2025-02-10", "2025-03-01"],
    "status": ["Delivered", "Delivered", "Returned", "Delivered", "Cancelled"]
})

orders
# Out:
#    order_id  customer_id   product     category  quantity  unit_price  \
# 0      1001            1     Mouse  Electronics         2         500
# 1      1002            2     Chair         Home         1        1200
# 2      1003            1   T-Shirt      Fashion         3         300
# 3      1004            3  Keyboard  Electronics         1         750
# 4      1005            4   Shampoo       Beauty         2         200
#
#    order_date     status
# 0  2025-01-05  Delivered
# 1  2025-01-12  Delivered
# 2  2025-02-03   Returned
# 3  2025-02-10  Delivered
# 4  2025-03-01  Cancelled
